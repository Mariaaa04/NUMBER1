# %%
print("  |  |  ","---------","  |  |  ","---------","  |  |  ",sep="\n")
# Out:
#   |  |
# ---------
#   |  |
# ---------
#   |  |

# %%
print("""   |  |  
----------
   |  |  
----------
   |  |  """)
# Out:
#    |  |
# ----------
#    |  |
# ----------
#    |  |

# %%
for i on range (1,42):
  if ((i%3==0) or (i%5==0)):
    print(i )
